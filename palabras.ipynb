# %%
import pandas as pd

# %%
df=pd.read_excel("/Libro1.xlsx")
df
# Out:
#        Término Número de Bits Número de Bytes  \
# 0         Byte         8 bits          1 byte
# 1    Half Word        16 bits         2 bytes
# 2         Word        32 bits         4 bytes
# 3  Double Word        64 bits         8 bytes
# 4    Quad Word       128 bits        16 bytes
# 5     Oct Word       256 bits        32 bytes
# 6     Hex Word       512 bits        64 bytes
# 7    Tera Word      1024 bits       128 bytes
#
#                                       Ejemplo de Uso
# 0                    Datos básicos, caracteres ASCII
# 1        Procesadores de 16 bits, sistemas embebidos
# 2  Procesadores de 32 bits, sistemas operativos a...
# 3  Procesadores modernos, sistemas operativos act...
# 4  Procesadores especializados, criptografía avan...
# 5   Procesamiento de gráficos, criptografía avanzada
# 6  Supercomputadoras, procesamiento de datos masivos
# 7   Aplicaciones científicas, simulaciones complejas

# %% [markdown]
# Las referencias para la información proporcionada son:
#
# 1. **Arquitectura de Computadoras**: Los términos como "half word", "word", "double word" y "quad word" son ampliamente utilizados en la arquitectura de computadoras para describir diferentes tamaños de datos que un procesador puede manejar.
# 2. **Procesadores y Sistemas Operativos**: Los tamaños de palabra varían según la generación de procesadores y los sistemas operativos que los soportan. Por ejemplo, los procesadores de 16 bits utilizan "half words", mientras que los procesadores modernos de 64 bits utilizan "double words".
# 3. **Aplicaciones Especializadas**: Términos como "oct word", "hex word" y "tera word" se utilizan en contextos más especializados, como el procesamiento de gráficos, criptografía avanzada y aplicaciones científicas.
#
# Si necesitas más detalles específicos o tienes alguna otra pregunta, ¡no dudes en decírmelo!
# IA:copilot
